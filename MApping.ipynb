# %% [markdown]
# # DATA VIZ

# %%
import numpy as np
import pandas as pd

import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import glob
import time
import csv

import h5py
import hdf5_getters
from hdf5_getters import *

from operator import methodcaller
# %load_ext autoreload

# %%
def retrieve_csv(filename, retrieve_as='string', folder='./data/'):
    data = []
    with open(folder+filename, 'r') as f:
        reader = csv.reader(f, delimiter=',')
        for row in reader:
            data.append(row)
            
    if(retrieve_as in ['integer', 'signed', 'unsigned', 'float']):
        data = [pd.to_numeric(item, errors='coerce', downcast=retrieve_as) if(len(item) > 0) else item for item in data]
            
    if(len(data) == 1):
        return data[0]
    else:
        return data

# %% [markdown]
# #### Retrieving the dataframe
#
# The data needs to be read only once from the .h5 file structure. After that, the created dataframe is saved into multiple .csv files, one per column: it is from these files that the dataframe is loaded for the rest of the analysis.
#
# The additional `index.csv` file specifies the datatype of each column, in particular, if a the data in the /csv file should be converted to numeric or not.

# %%
data = pd.DataFrame()

# %%
index = retrieve_csv('index.csv')
#index.remove(['segments pitches', 'object'])
#index.remove(['segments timbre', 'object'])
len(index)
# Out:
# 48

# %%
start_time = time.time()
for idx in index:
    print(idx)
    column_name = idx[0]
    retrieve_as = idx[1]
    filename = column_name.replace(' ', '_')+'.csv'
    data[column_name] = retrieve_csv(filename, retrieve_as=retrieve_as)
print("--- Execution time: %s seconds ---" % (time.time() - start_time))
# Out:
# ['num songs', 'object']
# ['artist familiarity', 'float']
# ['artist hotttnesss', 'float']
# ['artist id', 'object']
# ['artist mbid', 'object']
# ['artist playmeid', 'object']
# ['artist 7digitalid', 'object']
# ['artist latitude', 'float']
# ['artist longitude', 'float']
# ['artist location', 'object']
# ['artist name', 'object']
# ['release', 'object']
# ['release 7digitalid', 'object']
# ['song id', 'object']
# ['song hotttnesss', 'float']
# ['title', 'object']
# ['track 7digitalid', 'object']
# ['similar artists', 'object']
# ['artist terms', 'object']
# ['artist terms freq', 'object']
# ['artist terms weight', 'object']
# ['analysis sample rate', 'object']
# ['audio md5', 'object']
# ['danceability', 'float']
# ['duration', 'float']
# ['end of fade in', 'float']
# ['energy', 'float']
# ['key', 'object']
# ['key confidence', 'float']
# ['loudness', 'float']
# ['mode', 'object']
# ['mode confidence', 'float']
# ['start of fade out', 'float']
# ['tempo', 'float']
# ['time signature', 'object']
# ['time signature confidence', 'float']
# ['track id', 'object']
# ['segments start', 'object']
# ['segments confidence', 'object']
# ['sections start', 'object']
# ['sections confidence', 'object']
# ['beats start', 'object']
# ['beats confidence', 'object']
# ['bars start', 'object']
# ['bars confidence', 'object']
# ['artist mbtags', 'object']
# ['artist mbtags count', 'object']
# ['year', 'integer']
# --- Execution time: 22.886890649795532 seconds ---

# %%
data.head(1)
# Out:
#   num songs  artist familiarity  artist hotttnesss              artist id  \
# 0         1            0.581794           0.401998  b'ARD7TVE1187B99BFB1'
#
#                                artist mbid artist playmeid artist 7digitalid  \
# 0  b'e77e51a5-4761-45b3-9847-2051f811e366'            4479            165270
#
#    artist latitude  artist longitude     artist location ...   \
# 0              NaN               NaN  b'California - LA' ...
#
#                                  segments confidence  \
# 0  [0.0, 1.0, 0.483, 0.137, 0.42, 1.0, 0.257, 1.0...
#
#                                       sections start  \
# 0  [0.0, 7.74554, 36.44331, 43.61667, 75.17954, 9...
#
#                                  sections confidence  \
# 0  [1.0, 1.0, 0.218, 0.133, 0.384, 0.326, 0.373, ...
#
#                                          beats start  \
# 0  [0.58521, 1.19196, 1.78893, 2.37813, 2.94247, ...
#
#                                     beats confidence  \
# 0  [0.834, 0.851, 0.65, 0.635, 0.532, 0.753, 0.62...
#
#                                           bars start  \
# 0  [0.58521, 2.94247, 5.14371, 7.74554, 10.36149,...
#
#                                      bars confidence artist mbtags  \
# 0  [0.643, 0.746, 0.722, 0.095, 0.091, 0.362, 0.4...            []
#
#   artist mbtags count year
# 0                  []    0
#
# [1 rows x 48 columns]

# %% [markdown]
# #### Formatting the dataframe

# %%
data.dtypes
# Out:
# num songs                     object
# artist familiarity           float32
# artist hotttnesss            float32
# artist id                     object
# artist mbid                   object
# artist playmeid               object
# artist 7digitalid             object
# artist latitude              float32
# artist longitude             float32
# artist location               object
# artist name                   object
# release                       object
# release 7digitalid            object
# song id                       object
# song hotttnesss              float32
# title                         object
# track 7digitalid              object
# similar artists               object
# artist terms                  object
# artist terms freq             object
# artist terms weight           object
# analysis sample rate          object
# audio md5                     object
# danceability                 float32
# duration                     float32
# end of fade in               float32
# energy                       float32
# key                           object
# key confidence               float32
# loudness                     float32
# mode                          object
# mode confidence              float32
# start of fade out            float32
# tempo                        float32
# time signature                object
# time signature confidence    float32
# track id                      object
# segments start                object
# segments confidence           object
# sections start                object
# sections confidence           object
# beats start                   object
# beats confidence              object
# bars start                    object
# bars confidence               object
# artist mbtags                 object
# artist mbtags count           object
# year                           int16
# dtype: object

# %%
#old stuff
def string_to_float_array(df, column):
    #clean the string
    clean_string = df[column].apply(lambda x: x.replace('[', '')
                                    .replace(']', '')
                                    .replace('\n', '')) 
  
    #split every term at every < > position (single space)
    array = map(methodcaller('split', ' '), clean_string)
    #remove every remaining empty string
    array = [list(filter(None, sublist)) for sublist in array]
    #convert to numeric  
    
    #this crashes because data in .csv is weird
    #note: #pd.to_numeric crashes on empty series []
    print((array[0]))
    array = [pd.to_numeric(sublist) for sublist in array if(sublist != None) ]
    print(len(array))
    return array

# %% [markdown]
# # FROM JSON

# %%
import json
strjson = open('data.json').read()
strjson = strjson
json = json.loads(strjson)

# %%
data = pd.read_json('data.json',orient='split')

# %%
data.head()
# Out:
#    year  artist latitude  artist longitude  artist hotttnesss   artist name  \
# 0  1999         41.22949         -75.87130           0.365294  An Albatross
# 1  2000         34.05349        -118.24532           0.791143   Linkin Park
# 2  2005         55.95415          -3.20277           0.484315      Idlewild
# 3  1997         40.71455         -74.00712           0.182554      Glampire
# 4  2008         50.91552           0.48883           0.585160         Keane
#
#             artist id                                       artist terms  \
# 0  AR70VWQ1187FB4D009  [noise rock, grindcore, power violence, math-c...
# 1  ARQUMH41187B9AF699  [rap metal, post-grunge, nu metal, rapcore, al...
# 2  AR2WOOQ1187B98E303  [post-grunge, indie rock, rock, acoustic, folk...
# 3  ARCKAB11187B9956C8  [pop rock, dark wave, big beat, rock, glam, br...
# 4  ARHHUDL1187B997966  [piano rock, british pop, alternative rock, ro...
#
#                                  artist terms weight  \
# 0  [1.0, 0.862974119335551, 0.8567292291134491, 0...
# 1  [1.0, 1.0, 0.9948875807720821, 0.9915362071532...
# 2  [1.0, 0.8730423204984571, 0.8259494306920241, ...
# 3  [1.0, 0.9845366809480021, 0.9602059308877691, ...
# 4  [1.0, 0.9999139895624931, 0.849344151927909, 0...
#
#                                      similar artists
# 0  [ARZQWB61187B9B43DD, AROYHVS12AA0D8CB5E, AR969...
# 1  [AR5H4CJ1187B9AE949, AREWALY1187B9A05A8, AR21F...
# 2  [ARFGTKK1187FB47E19, ARHPPJK1187B9AC897, AR3GZ...
# 3  [AR183IH1187B9AC2F0, ARUU5YV1187FB4B175, ARROJ...
# 4  [ARVN9FZ1187FB393F1, ARQNR1G1187B9AE88F, ARJ7K...

# %%
data.shape
# Out:
# (322, 9)

# %% [markdown]
# #### Basic statistics
#
# - ranges, mean, median, ...
# - graphs

# %% [markdown]
# We give a basic overview of the (most important) features of the songs, using pandas `describe()` method.

# %%
def describe(data, column, include_undefined):
    if(include_undefined):
        return pd.DataFrame(data[column]).describe()
    else:
        return pd.DataFrame(data[data[column] != 0][column]).describe()

# %%
def set_ticks_wtih_step(ax, step):
    ticks = ax.xaxis.get_ticklocs()
    ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
    ax.xaxis.set_ticks(ticks[::step])
    ax.xaxis.set_ticklabels(ticklabels[::step]);

# %%
data.columns
# Out:
# Index(['year', 'artist latitude', 'artist longitude', 'artist hotttnesss',
#        'artist name', 'artist id', 'artist terms', 'artist terms weight',
#        'similar artists'],
#       dtype='object')

# %%
notnull = data[(data['year']>0) & (data['artist latitude'].notnull())].copy()
notnull.shape
# Out:
# (322, 9)

# %%
notnull['genre'] = notnull['artist terms'].apply(lambda x : "rock" if "xcwfgqdsfgqsdfrock" in x[0:9] else x[0])

# %%
notnull[notnull['genre'].str.contains('rock')]['genre'].value_counts()
# Out:
# country rock            18
# pop rock                12
# indie rock               7
# soft rock                6
# blues-rock               6
# garage rock              5
# folk rock                5
# alternative rock         4
# comedy rock              4
# rock                     4
# modern rock              3
# christian rock           3
# southern rock            2
# classic rock             2
# dance rock               2
# psychedelic rock         2
# noise rock               2
# experimental rock        2
# art rock                 2
# hard rock                2
# progressive rock         2
# space rock               1
# instrumental rock        1
# piano rock               1
# glam rock                1
# alternative pop rock     1
# rockabilly               1
# symphonic rock           1
# kraut rock               1
# roots rock               1
# math rock                1
# Name: genre, dtype: int64

# %%
notnull['genre'].value_counts()
# Out:
# country rock               18
# pop rock                   12
# indie rock                  7
# new wave                    6
# disco                       6
# trip hop                    6
# blues-rock                  6
# soft rock                   6
# ballad                      6
# garage rock                 5
# power pop                   5
# folk rock                   5
# hip hop                     5
# comedy rock                 4
# alternative rock            4
# indie pop                   4
# future jazz                 4
# rock                        4
# dance pop                   4
# singer-songwriter           4
# chicago blues               4
# shoegaze                    3
# techno                      3
# post-hardcore               3
# speed metal                 3
# post-grunge                 3
# intelligent dance music     3
# alternative metal           3
# british pop                 3
# electro                     3
#                            ..
# jump blues                  1
# chill-out                   1
# bluegrass                   1
# math rock                   1
# new romantic                1
# gabba                       1
# christian hip hop           1
# brazilian pop music         1
# neo soul                    1
# reggaeton                   1
# polka                       1
# emo                         1
# bass music                  1
# ragtime                     1
# grunge                      1
# orchestra                   1
# blue-eyed soul              1
# piano rock                  1
# italian disco               1
# tropical                    1
# hardcore punk               1
# rap metal                   1
# honky tonk                  1
# sadcore                     1
# dirty south rap             1
# tribal house                1
# celtic fusion               1
# punk                        1
# massachusetts               1
# math-core                   1
# Name: genre, Length: 162, dtype: int64

# %%
bluerock = notnull[notnull['genre'].str.contains('folk rock')]

# %%
bluerock['year'].value_counts()
# Out:
# 2006    64
# 2007    51
# 2005    50
# 2003    50
# 2008    47
# 2009    45
# 1996    42
# 2001    36
# 2004    35
# 2002    35
# 2000    32
# 1998    25
# 1994    24
# 1991    22
# 1992    21
# 1997    19
# 1999    18
# 1993    17
# 1995    17
# 1971    15
# 1990    14
# 1977    12
# 1970    11
# 2010    11
# 1967    11
# 1974    11
# 1987     9
# 1989     9
# 1972     9
# 1973     9
# 1976     9
# 1986     8
# 1968     8
# 1969     8
# 1978     8
# 1975     8
# 1985     7
# 1988     7
# 1984     6
# 1964     6
# 1983     5
# 1979     4
# 1980     4
# 1981     4
# 1966     4
# 1965     3
# 1982     2
# 1959     2
# 1956     1
# 1952     1
# Name: year, dtype: int64

# %%
import folium

# %%
f = folium.map.FeatureGroup()
for lat,lng, in zip(bluerock['artist latitude'],bluerock['artist longitude']):
    f.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10,
            fill_opacity=0.6)
        )

# %%
m = folium.Map([46,4], zoom_start=5)
m.add_child(f)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium.plugins as plugins

# %%
yeararray = bluerock[['artist latitude','artist longitude','year']].groupby('year').apply(lambda x:x.values[:,0:3] )
m = folium.Map([46,4], zoom_start=5)


for arr in (yeararray):
    f = folium.map.FeatureGroup(overlay =True)
    for lat,lng,year in arr :
        f.add_child(
            folium.features.CircleMarker(
                [lat, lng],
                radius=10,
                fill_opacity=0.6)
            )
    f.layer_name = str(year)
    m.add_child(f)
folium.LayerControl().add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
